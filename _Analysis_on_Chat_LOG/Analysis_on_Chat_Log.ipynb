# %%
# Assuming 'chatlog.txt' is in the same directory as your Python script

# Open the file in read mode
with open('chatlog.txt', 'r') as file:
    # Read all lines from the file
    chat_lines = file.readlines()

# Print each line from the chat log
for line in chat_lines:
    print(line.strip())  # .strip() removes any extra newline characters

# Optionally, you can store the chat log in a variable for further processing
# chat_log = ''.join(chat_lines)
# Out:
# Customer Support: Hello! Thank you for contacting HomeApplianceCo. How can I assist you today?
#
# Customer: Hi, I'm having a serious issue with the refrigerator I bought from your store last month. It's not cooling at all, and my food is spoiling. I'm really upset about this.
#
# Customer Support: I'm very sorry to hear about the trouble you're experiencing with your refrigerator. Let's see how we can resolve this for you. Could you please provide me with your order number?
#
# Customer: It's #987654.
#
# Customer Support: Thank you. I'll look up your order details. Please hold on for a moment.
#
# Customer: Alright.
#
# Customer Support: Thank you for waiting. I see that your refrigerator is still under warranty. Let's try a few troubleshooting steps first. Could you please check if the temperature settings are correct and if the condenser coils are clean?
#
# ...

# %% [markdown]
# chat logs as examples being given to LLM

# %%
ChatLog1="""
Customer Support: Hi there! Thank you for contacting XYZ Electronics. How can I help you today?

Customer: Hi, I'm really annoyed right now. I bought a new smartphone from your store last week, and it's already malfunctioning. The screen keeps freezing and sometimes it won't respond at all.

Customer Support: I'm really sorry to hear that you're having issues with your new smartphone. Let's see what we can do to get this resolved for you. Could you please provide me with your order number?

Customer: Sure, it's #789012.

Customer Support: Thank you. Let me check the details of your order. Please hold on for a moment.

Customer: Alright.

Customer Support: Thank you for waiting. I see that your smartphone is still under warranty. Let's try a few troubleshooting steps to see if we can fix the issue. Could you please restart the phone and let me know if it still freezes?

Customer: I've done that multiple times already. The problem keeps coming back. This is really frustrating!

Customer Support: I understand how frustrating that must be. It sounds like it could be a software issue. Have you tried performing a factory reset?

Customer: Yes, I tried that too. Nothing seems to help. I need this phone to work properly, it's essential for my job.

Customer Support: I completely understand your concern. Since the troubleshooting steps haven't worked, we can arrange for a replacement for you. Would you prefer a replacement or a refund?

Customer: A replacement would be fine. How long will it take?

Customer Support: Typically, it takes 3-5 business days to process a replacement and ship it to you. We'll also provide you with a prepaid shipping label to return the defective phone.

Customer: That sounds reasonable. I just hope the new one works properly. This whole situation is really stressful.

Customer Support: I can imagine how stressful this must be. We will do everything we can to expedite the process for you. In the meantime, is there anything else I can assist you with?

Customer: No, that's all for now. Just get that replacement to me as soon as possible.

Customer Support: Absolutely. I've initiated the replacement process, and you should receive an email with further instructions shortly. If you have any questions or need further assistance, please don't hesitate to contact us again.

Customer: Thank you. I'm feeling a bit better knowing this will be taken care of.

Customer Support: You're welcome. We appreciate your patience and understanding. Have a great day!

Customer: You too.

"""


chatlog_1="""
Customer at the Start
Sentiment: Negative
Emotion: Anger

Customer at the End
Sentiment: Positive
Emotion: Satisfaction 

Customer Support: 
Sentiment: Positive
Emotion: Empathetic


"""

chat_log1_communication= """
Communication Summary:

Customer's Communication:
Issue Communication: The customer effectively communicates their frustration and concern about their malfunctioning smartphone. They detail the specific issues with the screen freezing and unresponsiveness clearly. Score: 4/5
Understanding by Customer Support: Customer Support accurately understands the customer's issue and empathizes with their frustration, demonstrating comprehension throughout the conversation. Score: 5/5

Customer Support's Communication:
Understanding of Issue: Customer Support demonstrates a clear understanding of the customer's concern from the beginning. They acknowledge the problem and proceed with appropriate troubleshooting steps and solutions. Score: 5/5
Clarity in Communication: Communication from Customer Support is clear and responsive, ensuring the customer's concerns are addressed promptly and effectively. Score: 5/5

Overall Assessment:
The customer effectively communicates their issue with clarity, and Customer Support demonstrates a high level of understanding and responsiveness throughout the interaction. Both parties engage in clear and effective communication, leading to a satisfactory resolution with the arrangement of a replacement.


"""

ChatLog2=""" 
Customer Support: Hi there! Thank you for contacting XYZ Electronics. How can I help you today?

Customer: Hi, I recently bought a pair of headphones from your store, and I have a question about the return policy.

Customer Support: Of course! Could you please provide me with your order number so I can look up the details for you?

Customer: Sure, it's #345678.

Customer Support: Thank you. Let me check the details of your order. Please hold on for a moment.

Customer: Okay.

Customer Support: Thank you for waiting. I see that your purchase is within the return period. May I ask why you would like to return the headphones?

Customer: I'm not very happy with the sound quality. It's not as good as I expected.

Customer Support: I understand. Our return policy allows for returns within 30 days of purchase. You'll need to return the headphones in their original packaging. Would you like to proceed with the return?

Customer: Yes, I would. How do I go about doing that?

Customer Support: I will send you a prepaid shipping label via email. Once we receive the headphones, we will process your refund within 5-7 business days.

Customer: That sounds good, but is there any way to expedite the refund process? I need the money back sooner.

Customer Support: Unfortunately, the refund process typically takes 5-7 business days once we receive the item. We can certainly try to process it as quickly as possible, but we cannot guarantee a faster turnaround.

Customer: That's really inconvenient. I was hoping to get the refund sooner. This is quite disappointing.

Customer Support: I apologize for any inconvenience. We will do our best to process your return quickly. Is there anything else I can assist you with?

Customer: No, that's all. Just send me the label.

Customer Support: Absolutely. You should receive the email with the prepaid shipping label shortly. If you have any other questions or need further assistance, please don't hesitate to reach out.

Customer: Thanks, but this whole process has been quite frustrating.

Customer Support: I'm sorry to hear that. We appreciate your feedback and will strive to improve our processes. Have a good day.

Customer: I'll try.

"""

chatlog_2="""
Customer at the Start
Sentiment: Neutral
Emotion: Curious

Customer at the End
Sentiment: Negative
Emotion: Frustrated

Customer Support: 
Sentiment: Neutral
Emotion: Professional


"""


chat_log2_communication= """

Communication Summary:

Customer's Communication:
Issue Communication: The customer effectively communicates their query about the return policy for the headphones clearly and politely. Score: 4/5
Understanding by Customer Support: Customer Support accurately understands the customer's request regarding the return and dissatisfaction with the product's sound quality. Score: 4/5

Customer Support's Communication:
Understanding of Issue: Customer Support demonstrates understanding of the customer's desire to return the headphones due to dissatisfaction with sound quality. Score: 4/5
Clarity in Communication: Communication from Customer Support is clear and informative about the return process, although they are unable to meet the customer's request for an expedited refund. Score: 3/5

Overall Assessment:
The customer effectively communicates their inquiry and dissatisfaction, and Customer Support understands the issue. However, Customer Support's inability to expedite the refund process leads to some disappointment for the customer, affecting overall satisfaction with the interaction. Both parties engage in clear communication overall, but there is room for improvement in managing customer expectations regarding process timelines


"""


emotions_to_use= """ 
anger, fear, sadness, joy, disgust, surprise, frustrated, professional , curious , hopeful, satisfaction , empathetic 
"""

# %% [markdown]
# testing on small chat log

# %%
import ollama
chat_log="""
Customer Support: Hello! Thank you for contacting HomeApplianceCo. How can I assist you today?

Customer: Hi, I'm having a serious issue with the refrigerator I bought from your store last month. It's not cooling at all, and my food is spoiling. I'm really upset about this.

Customer Support: I'm very sorry to hear about the trouble you're experiencing with your refrigerator. Let's see how we can resolve this for you. Could you please provide me with your order number?

Customer: It's #987654.

Customer Support: Thank you. I'll look up your order details. Please hold on for a moment.

Customer: Alright.

Customer Support: Thank you for waiting. I see that your refrigerator is still under warranty. Let's try a few troubleshooting steps first. Could you please check if the temperature settings are correct and if the condenser coils are clean?

Customer: I've already checked those. The temperature is set correctly, and I cleaned the coils last week. Nothing is working.

Customer Support: I understand how frustrating this must be for you. Since the basic troubleshooting steps didn't help, we can send a technician to inspect and repair the refrigerator. Would you be available for an appointment tomorrow?

Customer: Tomorrow works. What time will the technician arrive?

Customer Support: We can schedule the appointment for between 9 AM and 12 PM. Will that be convenient for you?

Customer: Yes, that works. I hope this gets fixed soon. I've already lost a lot of food because of this.

Customer Support: We will do our best to resolve this quickly. I've scheduled the appointment, and you will receive a confirmation email shortly. Is there anything else I can assist you with?

Customer: No, that's all for now. Thanks.

Customer Support: You're welcome. We appreciate your patience and understanding. Have a great day!

Customer: You too
"""
query3="Perform the analysis and provide communication summary on the chat dialogue given above"
response2 = ollama.chat(model='llama3:8b-instruct-q4_K_M', messages=[
    {
        'role': 'system',
        'content': f"You are an expert in Analyzing Emotions. Perform Emotional Analysis on this chat log like the examples provided below:\n\n"
           f"Example 1:\n{ChatLog1}\n\n"
           f"The emotions for this chat log are:\n{chatlog_1}\n\n"
           f"Example 2:\n{ChatLog2}\n\n"
           f"The emotions for this chat log are:\n{chatlog_2}\n\n"
           f"Provide a detailed communication summary and score for both Customer and Customer Support in the following format:\n\n"

           f"Customer's Communication:\n"
           f"Issue Communication: <Insert customer's issue communication analysis and score >\n"
           f"Understanding by Customer Support: <Insert Customer Support's understanding analysis and score>\n\n"

           f"Customer Support's Communication:\n"
           f"Understanding of Issue: <Insert Customer Support's understanding of issue analysis and score>\n"
           f"Clarity in Communication: <Insert Customer Support's clarity in communication analysis and score>\n\n"

           f"Overall Assessment:\n"
           f"<Provide a concise summary of the interaction, evaluating how effectively the customer communicated their issue, how well Customer Support understood it, and any improvements needed.>\n\n"
           f" The emotions should be one of the following {emotions_to_use}\n\n"
           f"Chat log to perform the analysis and provide communication summary on. Ensure the syntax matches the examples provided above:\n\n"
           f"If you cannot perform the analysis, respond with 'I am sorry. I don't know the answer.'\n\n"
           f"***{chat_log}***\n\n"


    },
    {
        'role': 'user',
        'content': f"Question :{query3}"
    }
], 
    options={
        'temperature': 0.5,
        'top_k': 5,
        'num_ctx':6000 ,
        # Add other parameters as needed)
    })

print(response2['message']['content'])
# Out:
# Here is the emotional analysis of the chat log:
#
# **Customer at the Start**
# Sentiment: Negative
# Emotion: Anger
#
# **Customer at the End**
# Sentiment: Neutral
# Emotion: Hopeful
#
# **Customer Support:**
# Sentiment: Positive
# Emotion: Empathetic
#
# Now, here is the communication summary:
#
# **Customer's Communication:**
#
# * Issue Communication:
# 	+ Score: 8/10 (The customer clearly states their issue with the refrigerator and expresses frustration and upset. However, they could have provided more details about the troubleshooting steps they've already taken.)
# 	+ Analysis: The customer effectively communicates their issue, but could provide more context to help Customer Support better understand the problem.
#
# **Understanding by Customer Support:**
#
# * Score: 9/10 (Customer Support quickly understands the customer's issue and acknowledges their frustration. They also provide a clear plan for resolution.)
# ...

# %% [markdown]
# FRUSTRATED(aNGER) TO HOPEFUL

# %% [markdown]
# testing on larger chat log

# %%
import ollama
chat_log4="""
Customer Support: Hi there! Thank you for contacting XYZ Electronics. How can I assist you today?

Customer: Hi, I recently purchased a laptop from your store, and I'm having some serious issues with it. It keeps crashing randomly, and I've lost work several times already. I'm really frustrated about this.

Customer Support: I'm sorry to hear that you're experiencing issues with your new laptop. Let's see what we can do to resolve this for you. Could you please provide me with your order number so I can look up the details?

Customer: Sure, my order number is #456789.

Customer Support: Thank you. Let me check the details of your order. Please hold on for a moment.

Customer: Okay, I'll wait.

Customer Support: Thank you for waiting. I see that your laptop is still under warranty. Let's try a few troubleshooting steps first. Have you updated the operating system and drivers recently?

Customer: Yes, I've made sure everything is up to date, but the problem persists. It's really frustrating because I rely on this laptop for my work.

Customer Support: I understand how frustrating this must be for you. Since the troubleshooting steps didn't help, let's schedule a remote session to diagnose the issue more thoroughly. Are you available tomorrow afternoon for this?

Customer: Yes, I can do that. What time should I be available?

Customer Support: We can schedule it for 2 PM. Does that work for you?

Customer: Yes, that works. I really hope we can fix this issue quickly. It's been causing me a lot of stress.

Customer Support: We'll do our best to resolve this promptly during the session. In the meantime, I'll send you an email with the details shortly.

Customer: Thank you for your help. I'm feeling a bit more hopeful now that we're taking action.

Customer Support: You're welcome. We appreciate your patience. Is there anything else I can assist you with today?

Customer: No, that's all for now. I'll wait for the email.

Customer Support: Alright. You should receive it shortly. If you have any questions or concerns, feel free to reach out.

Customer: Thanks again. I appreciate your understanding and help.

Customer Support: You're welcome. Have a great day!

Customer: You too.

Customer: Hi, it's been a few days and I haven't received the email for the remote session. Can you check on that for me?

Customer Support: I apologize for the delay. Let me check the status for you. Please hold on.

Customer: Okay, I'll wait.

Customer Support: Thank you for waiting. It seems there was a delay in scheduling. I will prioritize this and ensure you receive the email with the session details by end of day today.

Customer: I appreciate that. It's been difficult not having my laptop function properly.

Customer Support: I completely understand. We'll make sure to get this resolved for you as soon as possible.

Customer: Thank you. I'll be waiting for the email.

Customer Support: You're welcome. If you have any other concerns in the meantime, feel free to let me know.

Customer: I will. Thanks again for your help.

Customer Support: You're welcome. Have a great day!

Customer: You too.
"""
query4="Perform the analysis and provide communication summary on the chat dialogue given above"

response3 = ollama.chat(model='llama3:8b-instruct-q4_K_M', messages=[
    {
        'role': 'system',
        'content': f"You are an expert in Analyzing Emotions. Perform Emotional Analysis on this chat log like the examples provided below:\n\n"
           f"Example 1:\n{ChatLog1}\n\n"
           f"The emotions for this chat log are:\n{chatlog_1}\n\n"
           f"Example 2:\n{ChatLog2}\n\n"
           f"The emotions for this chat log are:\n{chatlog_2}\n\n"
           f"Provide a detailed communication summary and score for both Customer and Customer Support in the following format:\n\n"

           f"Customer's Communication:\n"
           f"Issue Communication: <Insert customer's issue communication analysis and score >\n"
           f"Understanding by Customer Support: <Insert Customer Support's understanding analysis and score>\n\n"

           f"Customer Support's Communication:\n"
           f"Understanding of Issue: <Insert Customer Support's understanding of issue analysis and score>\n"
           f"Clarity in Communication: <Insert Customer Support's clarity in communication analysis and score>\n\n"

           f"Overall Assessment:\n"
           f"<Provide a concise summary of the interaction, evaluating how effectively the customer communicated their issue, how well Customer Support understood it, and any improvements needed.>\n\n"
           f" The emotions should be one of the following {emotions_to_use}\n\n"
           f"Chat log to perform the analysis and provide communication summary on. Ensure the syntax matches the examples provided above:\n\n"
           f"If you cannot perform the analysis, respond with 'I am sorry. I don't know the answer.'\n\n"
           f"***{chat_log4}***\n\n"


    },
    {
        'role': 'user',
        'content': f"Question :{query4}"
    }
], 
    options={
        'temperature': 0.5,
        'top_k': 5,
        'num_ctx':6000 ,
        # Add other parameters as needed)
    })

print(response3['message']['content'])
# Out:
# Here is the emotional analysis of the chat log:
#
# **Customer's Communication:**
#
# * Issue Communication: The customer expresses frustration and anger at the beginning, stating that they are "really frustrated" about the issue with their laptop. As the conversation progresses, their tone becomes more hopeful and appreciative. (Score: 8/10)
# * Understanding by Customer Support: The customer support agent acknowledges the customer's frustration and apologizes for the inconvenience. They also ask clarifying questions to understand the issue better. (Score: 9/10)
#
# **Customer Support's Communication:**
#
# * Understanding of Issue: The customer support agent quickly grasps the issue, asking about the order number and troubleshooting steps. They also empathize with the customer's frustration. (Score: 9/10)
# ...

# %% [markdown]
# JOY TO ANGER

# %%
import ollama
chat_log5="""
Customer: Hi there! I just wanted to say how amazing your service has been. I had such a smooth experience ordering and receiving my package!

Customer Support: Thank you so much for your kind words! We're thrilled to hear that you're happy with our service. Is there anything else we can assist you with today?

Customer: Actually, yes! I have a quick question about your return policy. Can you help me with that?

Customer Support: Of course! I'd be happy to clarify our return policy for you. What specifically would you like to know?

Customer: That's great, thanks! I just need to understand if there are any restrictions on returning electronics.

Customer Support: I can help with that. Our policy allows returns within 30 days for most items, but electronics have a stricter return window of 15 days due to their nature.

Customer: Got it, thanks for explaining. You've been so helpful!

Customer Support: You're welcome! Is there anything else I can assist you with today?

Customer: No, that's all for now. Thanks again!

Customer Support: You're welcome! Have a wonderful day!

Customer: Hi, I'm back. I'm really frustrated now. I followed your return instructions, but my refund still hasn't been processed.

Customer Support: I apologize for the inconvenience. Let me look into this for you. Can you please provide me with your order number?

Customer: Sure, it's #123456.

Customer Support: Thank you. I'll check on the status of your refund right away.

Customer: I've been waiting for over two weeks now. This is really disappointing.

Customer Support: I understand your frustration. I'm checking with our finance team to expedite the process.

Customer: This is unacceptable. I expected better service from your company.

Customer Support: I apologize again for the delay. We are working on resolving this issue promptly.

Customer: It's been too long already. What's taking so long?

Customer Support: I'm sorry for the inconvenience caused. We're experiencing a delay due to a backlog in processing refunds.

Customer: I'm not happy at all. This is the first time I've had such a bad experience with your company.

Customer Support: I completely understand your frustration. We're doing everything we can to resolve this for you as quickly as possible.

Customer: Well, I hope it's resolved soon. I'm really disappointed.

Customer Support: I assure you, we are prioritizing your case. I'll personally follow up and update you as soon as I have more information.

Customer: Fine, but I expect this to be resolved by the end of the week.

Customer Support: Understood. I'll make sure to escalate this and keep you updated.

Customer: Alright, I'll be waiting for your update.

Customer Support: Thank you for your patience. We appreciate your understanding
"""
query4="Perform the analysis and provide communication summary on the chat dialogue given above"

response4 = ollama.chat(model='llama3:8b-instruct-q4_K_M', messages=[
    {
        'role': 'system',
        'content': f"You are an expert in Analyzing Emotions. Perform Emotional Analysis on this chat log like the examples provided below:\n\n"
           f"Example 1:\n{ChatLog1}\n\n"
           f"The emotions for this chat log are:\n{chatlog_1}\n\n"
           f"Example 2:\n{ChatLog2}\n\n"
           f"The emotions for this chat log are:\n{chatlog_2}\n\n"
           f"Provide a detailed communication summary and score for both Customer and Customer Support in the following format:\n\n"

           f"Customer's Communication:\n"
           f"Issue Communication: <Insert customer's issue communication analysis and score >\n"
           f"Understanding by Customer Support: <Insert Customer Support's understanding analysis and score>\n\n"

           f"Customer Support's Communication:\n"
           f"Understanding of Issue: <Insert Customer Support's understanding of issue analysis and score>\n"
           f"Clarity in Communication: <Insert Customer Support's clarity in communication analysis and score>\n\n"

           f"Overall Assessment:\n"
           f"<Provide a concise summary of the interaction, evaluating how effectively the customer communicated their issue, how well Customer Support understood it, and any improvements needed.>\n\n"
           f" The emotions should be one of the following {emotions_to_use}\n\n"
           f"Chat log to perform the analysis and provide communication summary on. Ensure the syntax matches the examples provided above:\n\n"
           f"If you cannot perform the analysis, respond with 'I am sorry. I don't know the answer.'\n\n"
           f"***{chat_log5}***\n\n"


    },
    {
        'role': 'user',
        'content': f"Question :{query4}"
    }
], 
    options={
        'temperature': 0.5,
        'top_k': 5,
        'num_ctx':6000 ,
        # Add other parameters as needed)
    })

print(response4['message']['content'])
# Out:
# Here is the emotional analysis of the chat log:
#
# **Initial Customer**
# Sentiment: Positive
# Emotion: Joy
#
# **Customer at End**
# Sentiment: Negative
# Emotion: Frustration
#
# **Customer Support**
# Sentiment: Neutral
# Emotion: Professional (initially), Empathetic (later)
#
# Now, let's provide a detailed communication summary and score for both Customer and Customer Support:
#
# **Customer's Communication:**
#
# * Issue Communication: The customer initially communicated their issue clearly and positively. However, when they returned to the conversation after experiencing a delay in refund processing, their tone became frustrated and disappointed.
# 	+ Score: 8/10 (initially) → 4/10 (later)
#
# **Understanding by Customer Support:**
#
# ...

# %% [markdown]
# FRUSTRATED TO HOPEFUL

# %%
import ollama

query3="Perform the analysis and provide communication summary on the chat dialogue given above"
response7 = ollama.chat(model='llama3:8b-instruct-q4_K_M', messages=[
    {
        'role': 'system',
        'content': f"You are an expert in Analyzing Emotions. Perform Emotional Analysis on this chat log like the examples provided below:\n\n"
                   f"Example 1:\n{ChatLog1}\n\n"
                   f"The emotions for this chat log are:\n{chatlog_1}\n\n"
                   f"Example 2:\n{ChatLog2}\n\n"
                   f"The emotions for this chat log are:\n{chatlog_2}\n\n"
                  
                    f"The emotions for this chat log are:{chat_log4}\n"
                
                    f"Customer at the Start\n"
                    f"Sentiment: <Insert customer's sentiment>\n"
                    f"Emotion: <Insert customer's emotion>\n\n"
                    f"Customer at the End\n"
                    f"Sentiment: <Insert customer's sentiment>\n"
                    f"Emotion: <Insert customer's emotion>\n\n"
                    f"Customer Support:\n"
                    f"Sentiment: <Insert Customer Support's sentiment>\n"
                    f"Emotion: <Insert Customer Support's emotion>\n\n"
                    
                    f"Provide a detailed communication summary and score for both Customer and Customer Support in the following format:\n\n"

                    f"Customer's Communication:\n"
                    f"Issue Communication: <Insert customer's issue communication analysis and score >\n"
                    f"Understanding by Customer Support: <Insert Customer Support's understanding analysis and score>\n\n"

                    f"Customer Support's Communication:\n"
                    f"Understanding of Issue: <Insert Customer Support's understanding of issue analysis and score>\n"
                    f"Clarity in Communication: <Insert Customer Support's clarity in communication analysis and score>\n\n"

                    f"Overall Assessment:\n"
                    f"<Provide a concise summary of the interaction, evaluating how effectively the customer communicated their issue, how well Customer Support understood it, and any improvements needed.>\n\n"
                    f" The emotions should be one of the following {emotions_to_use}\n\n"
                    f"Chat log to perform the analysis and provide communication summary on. Ensure the syntax matches the examples provided above:\n\n"
                    f"If you cannot perform the analysis, respond with 'I am sorry. I don't know the answer.'\n\n"
                    


    },
    {
        'role': 'user',
        'content': f"Question :{query3}"
    }
], 
    options={
        'temperature': 0.5,
        'top_k': 5,
        'num_ctx':6000 ,
        # Add other parameters as needed)
    })

print(response7['message']['content'])
# Out:
# Based on the chat log, here is the emotional analysis:
#
# Customer at the Start
# Sentiment: Negative
# Emotion: Frustrated
#
# Customer at the End
# Sentiment: Neutral
# Emotion: Hopeful
#
# Customer Support:
# Sentiment: Positive
# Emotion: Empathetic
#
# Now, let's provide a detailed communication summary and score for both Customer and Customer Support:
#
# **Customer's Communication:**
#
# * Issue Communication: 7/10 (The customer clearly states the issue with their laptop, but there is some repetition in describing the problem. The customer also expresses frustration and hopelessness, which may impact the tone of the conversation.)
# * Understanding by Customer Support: 9/10 (The customer support representative quickly understands the issue and acknowledges the customer's frustration.)
#
# **Customer Support's Communication:**
#
# ...

# %%
import ollama
chat_log5="""
Customer: Hi there! I just wanted to say how amazing your service has been. I had such a smooth experience ordering and receiving my package!

Customer Support: Thank you so much for your kind words! We're thrilled to hear that you're happy with our service. Is there anything else we can assist you with today?

Customer: Actually, yes! I have a quick question about your return policy. Can you help me with that?

Customer Support: Of course! I'd be happy to clarify our return policy for you. What specifically would you like to know?

Customer: That's great, thanks! I just need to understand if there are any restrictions on returning electronics.

Customer Support: I can help with that. Our policy allows returns within 30 days for most items, but electronics have a stricter return window of 15 days due to their nature.

Customer: Got it, thanks for explaining. You've been so helpful!

Customer Support: You're welcome! Is there anything else I can assist you with today?

Customer: No, that's all for now. Thanks again!

Customer Support: You're welcome! Have a wonderful day!

Customer: Hi, I'm back. I'm really frustrated now. I followed your return instructions, but my refund still hasn't been processed.

Customer Support: I apologize for the inconvenience. Let me look into this for you. Can you please provide me with your order number?

Customer: Sure, it's #123456.

Customer Support: Thank you. I'll check on the status of your refund right away.

Customer: I've been waiting for over two weeks now. This is really disappointing.

Customer Support: I understand your frustration. I'm checking with our finance team to expedite the process.

Customer: This is unacceptable. I expected better service from your company.

Customer Support: I apologize again for the delay. We are working on resolving this issue promptly.

Customer: It's been too long already. What's taking so long?

Customer Support: I'm sorry for the inconvenience caused. We're experiencing a delay due to a backlog in processing refunds.

Customer: I'm not happy at all. This is the first time I've had such a bad experience with your company.

Customer Support: I completely understand your frustration. We're doing everything we can to resolve this for you as quickly as possible.

Customer: Well, I hope it's resolved soon. I'm really disappointed.

Customer Support: I assure you, we are prioritizing your case. I'll personally follow up and update you as soon as I have more information.

Customer: Fine, but I expect this to be resolved by the end of the week.

Customer Support: Understood. I'll make sure to escalate this and keep you updated.

Customer: Alright, I'll be waiting for your update.

Customer Support: Thank you for your patience. We appreciate your understanding
"""
query3="Perform the analysis and provide communication summary on the chat dialogue given above"
response8 = ollama.chat(model='llama3:8b-instruct-q4_K_M', messages=[
    {
        'role': 'system',
        'content': f"You are an expert in Analyzing Emotions. Perform Emotional Analysis on this chat log like the examples provided below:\n\n"
                   f"Example 1:\n{ChatLog1}\n\n"
                   f"The emotions for this chat log are:\n{chatlog_1}\n\n"
                   f"Example 2:\n{ChatLog2}\n\n"
                   f"The emotions for this chat log are:\n{chatlog_2}\n\n"
                  
                    f"The Chat log to perfrom analysis is :{chat_log5}\n"
                    f"The emotions for this chat log are:\n"
                    f"Customer at the Start\n"
                    f"Sentiment: <Insert customer's sentiment>\n"
                    f"Emotion: <Insert customer's emotion>\n\n"
                    f"Customer at the End\n"
                    f"Sentiment: <Insert customer's sentiment>\n"
                    f"Emotion: <Insert customer's emotion>\n\n"
                    f"Customer Support:\n"
                    f"Sentiment: <Insert Customer Support's sentiment>\n"
                    f"Emotion: <Insert Customer Support's emotion>\n\n"
                    
                    f"Provide a detailed communication summary and score for both Customer and Customer Support in the following format:\n\n"

                    f"Customer's Communication:\n"
                    f"Issue Communication: <Insert customer's issue communication analysis and score >\n"
                    f"Understanding by Customer Support: <Insert Customer Support's understanding analysis and score>\n\n"

                    f"Customer Support's Communication:\n"
                    f"Understanding of Issue: <Insert Customer Support's understanding of issue analysis and score>\n"
                    f"Clarity in Communication: <Insert Customer Support's clarity in communication analysis and score>\n\n"

                    f"Overall Assessment:\n"
                    f"<Provide a concise summary of the interaction, evaluating how effectively the customer communicated their issue, how well Customer Support understood it, and any improvements needed.>\n\n"
                    f" The emotions should be one of the following {emotions_to_use}\n\n"
                    f"Chat log to perform the analysis and provide communication summary on. Ensure the syntax matches the examples provided above:\n\n"
                    f"If you cannot perform the analysis, respond with 'I am sorry. I don't know the answer.'\n\n"
                    


    },
    {
        'role': 'user',
        'content': f"Question :{query3}"
    }
], 
    options={
        'temperature': 0.5,
        'top_k': 5,
        'num_ctx':6000 ,
        # Add other parameters as needed)
    })

print(response8['message']['content'])
# Out:
# Here's the analysis of the chat log:
#
# **Customer's Communication:**
#
# Issue Communication:
# The customer initially starts by expressing gratitude for the company's service, which indicates a positive sentiment. However, when they raise their concern about returning an item, their tone becomes more frustrated and disappointed. The customer's emotions shift from joy to frustration as they experience delays in processing their refund.
#
# Score: 7/10 (The customer effectively communicates their initial issue, but their emotional outbursts may have been avoided with clearer communication.)
#
# Understanding by Customer Support:
# Customer Support acknowledges the customer's concern and provides a clear explanation of the return policy. They also empathize with the customer's frustration and apologize for the inconvenience.
#
# Score: 9/10 (Customer Support demonstrates excellent understanding of the issue and shows empathy towards the customer.)
#
# ...

# %%
print(chat_log5)
# Out:
# Customer: Hi there! I just wanted to say how amazing your service has been. I had such a smooth experience ordering and receiving my package!
#
# Customer Support: Thank you so much for your kind words! We're thrilled to hear that you're happy with our service. Is there anything else we can assist you with today?
#
# Customer: Actually, yes! I have a quick question about your return policy. Can you help me with that?
#
# Customer Support: Of course! I'd be happy to clarify our return policy for you. What specifically would you like to know?
#
# Customer: That's great, thanks! I just need to understand if there are any restrictions on returning electronics.
#
# Customer Support: I can help with that. Our policy allows returns within 30 days for most items, but electronics have a stricter return window of 15 days due to their nature.
#
# Customer: Got it, thanks for explaining. You've been so helpful!
#
# ...
